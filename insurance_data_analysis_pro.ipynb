# %% [markdown]
# Problem Statement:
# An insurance agency, ABC Insurance, has a large dataset containing information about their policyholders and claims. They want to perform exploratory data analysis (EDA) on this dataset to gain insights that can help them make better business decisions and improve their operations.
#
# The agency wants to analyze the different body types and the environment that affect the premium. The disease's effect or the cost of treatment differs depending on the circumstances. For example, a smoker's medical insurance premium may be higher than that of a healthy person, because smokers are more likely to develop chronic diseases. The agency wants to analyze the data to research healthcare premium costs.
#
# Objective: To analyze the dataset that will help to create a model that will predict the cost of medical insurance based on various input features
#
# Domain: Healthcare
#
# Dataset: insurance dataset (insurance.csv)

# %% [markdown]
# 1.Import libraries such as Pandas, matplotlib, NumPy, and seaborn and load the  insurance dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
insurance=pd.read_csv('insurance.csv')

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# 2.Check the shape of the data along with the data types of the column

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# 3.Check missing values in the dataset and find the appropriate measures to fill in the missing values

# %%
insurance.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# 4.Explore the relationship between the feature and target column using a count plot of categorical columns and a scatter plot of numerical columns

# %%
corr_cols=['age','children','bmi','charges']
corr_df=insurance[corr_cols]

# %%
corr_df.corr()
# Out:
#                age  children       bmi   charges
# age       1.000000  0.042469  0.109272  0.299008
# children  0.042469  1.000000  0.012759  0.067998
# bmi       0.109272  0.012759  1.000000  0.198341
# charges   0.299008  0.067998  0.198341  1.000000

# %% [markdown]
# countplot for sex

# %%
sns.countplot(x='sex',hue='sex',data=insurance)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#countplot for region

# %%
sns.countplot(x='region',hue='region',data=insurance)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
#count plot for smoker

# %%
sns.countplot(x='smoker',hue='smoker',data=insurance)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
### scatter plot for age and bmi.

plt.scatter(x=insurance['age'],y=insurance['bmi'])
plt.show()

# %%
### scatter plot for age and children.

plt.scatter(x=insurance['age'],y=insurance['children'])
plt.show()

# %%
### sactter plot for age and charges

plt.scatter(x=insurance['age'],y=insurance['charges'])
plt.show()

# %%
### sactter plot for bmi and age

plt.scatter(x=insurance['bmi'],y=insurance['age'])
plt.show()

# %%
### sactter plot for bmi and children

plt.scatter(x=insurance['bmi'],y=insurance['children'])
plt.show()

# %%
### sactter plot for bmi and charges

plt.scatter(x=insurance['bmi'],y=insurance['charges'])
plt.show()

# %%
### sactter plot for children and bmi

plt.scatter(x=insurance['children'],y=insurance['bmi'])
plt.show()

# %%
### sactter plot for children and age

plt.scatter(x=insurance['children'],y=insurance['age'])
plt.show()

# %%
### sactter plot for chidren and charges

plt.scatter(x=insurance['children'],y=insurance['charges'])
plt.show()

# %%
### sactter plot for charges and bmi

plt.scatter(x=insurance['charges'],y=insurance['bmi'])
plt.show()

# %%
### sactter plot for charges and children

plt.scatter(x=insurance['charges'],y=insurance['children'])
plt.show()

# %%
### sactter plot for charges and age

plt.scatter(x=insurance['charges'],y=insurance['age'])
plt.show()

# %% [markdown]
# To get the relationship together, we can use the pair plot using seaborn.

# %%
sns.pairplot(data=insurance)

# %% [markdown]
# Pairplot will combine both the univariate  and bivariate comparisons together.

# %%
sns.scatterplot(data=insurance,x='age',y='charges',hue='smoker')
plt.show()

# %% [markdown]
# In the above scatter plopt depicts, the age and charges have positive relationship ;as the ages increase the charges for the smokers increases
# compared to the non-smoker.For instance,a non smoker of age 50 pays 30,000 as charges on the other side a smoker of age 50 pays near to 60,000
# as charges.
